# %% [markdown]
# <a href="https://colab.research.google.com/github/hjn14133/STAT/blob/main/Z_score_Confidence_Interval_varieties.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as st
import pandas as pd

# %%
#data = pd.read_csv('firetowerFiber_USDA.csv')
#data = pd.read_csv('FT_join_file.csv')
data = pd.read_csv('FT_join_JH.csv')

# %%
variety = data['Variety_1']

variety.unique()
# Out:
# array(['           dp 1646 b2xf', '            dg3799 b3xf',
#        '            dg3615 b3xf'], dtype=object)

# %%
var_1 = data[data['Variety_1'] =='           dp 1646 b2xf']
var_2 = data[data['Variety_1'] =='            dg3799 b3xf']
var_3 = data[data['Variety_1'] =='            dg3615 b3xf']

feature1 = var_1['Mic']
feature2 = var_2['Mic']
feature3 = var_3['Mic']

# %%
#for i in data['Variety_1']:

# %%
# create 90% confidence interval for feature mean value
st.t.interval(alpha=0.90, df=len(feature)-1, 
              loc=np.mean(feature), scale=st.sem(feature1))
# Out:
# (4.092033147309925, 4.097304843376042)

# %%
# Confidence Interval with Z-statistics for 1st variety

import matplotlib.pyplot as plt
import statistics
import seaborn as sns
import math


# Confidence Interval with Z-statistics for 3rd variety
plt.xlabel('Mic')
plt.ylabel('density')
plt.vlines(np.mean(feature1),0,0.003)
sns.distplot(feature1, hist=False)
plt.show()

#  mean, standard deviation and standard error
mean  = np.mean(feature1)           # mean
sigma = statistics.stdev(feature1)  # standard deviation
sem   = st.sem(feature1)   

print('mean:\t\t\t{:.4f}'.format(mean))
print('standard deviation:\t{:.4f}'.format(sigma))
print('standard error:\t\t{:.4f}'.format(sem))

confidenceLevel = .90
numOfTails      = 2
alpha           = (1 - confidenceLevel)/numOfTails

#  Percent Point Function
#  - calculates z-critical from (1-alpha)
z_critical = st.norm.ppf(1 - alpha)

# confidence Interval formula
lowerCI = mean - (z_critical * sigma)
upperCI = mean + (z_critical * sigma)

print('Step 2a:  Calculate z-critical for Confidence Level {:.0%} with {} tails.'.format(confidenceLevel,numOfTails))
print('Confidence Level:\t{:.0%}'.format(confidenceLevel))
print('Number of Tails:\t{}'.format(numOfTails))
print('alpha:\t\t\t{:.4f}'.format(alpha))
print('z-critical value:\t{:.4f}  <---'.format(z_critical))

print('\nConfidence Interval:\nlower CI\t\t{:.4f}'.format(lowerCI))
print('upper CI:\t\t{:.4f}'.format(upperCI))

usda = 4.24
#  PLOT CONFIDENCE INTERVAL
plt.figure(figsize=(10,6))
plt.title('Micronaire for dp 1646 b2xf\nz-statistics - Confidence Level = {:.0%} '.format(confidenceLevel), fontsize=16)
plt.xlabel('Micronaire')
plt.ylabel('density')

labelCI=("lower CI:  {:.4f}\nupper CI:   {:.4f}".format(lowerCI,upperCI))
#labelCI=("upper CI: {:.4f}\n".format(upperCI))
labelUS=("usda: {:.4f}".format(usda))
labelME=("\nmean:  {:.4f}".format(mean))

plt.vlines([lowerCI, upperCI],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelCI,color='blue',ls='--')
plt.vlines([usda],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelUS,color='red',ls='--')

plt.vlines(mean,0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)*.5),label=labelME,color='green')
plt.legend(loc='best')

sns.distplot(feature1, hist=True)
plt.show()

# %%
# Confidence Interval with Z-statistics for 2nd variety

import matplotlib.pyplot as plt
import statistics
import seaborn as sns
import math

plt.xlabel('Mic')
plt.ylabel('density')
plt.vlines(np.mean(feature2),0,0.003)
sns.distplot(feature2, hist=False)
plt.show()

#  mean, standard deviation and standard error
mean  = np.mean(feature2)           # mean
sigma = statistics.stdev(feature2)  # standard deviation
sem   = st.sem(feature2)   

print('mean:\t\t\t{:.4f}'.format(mean))
print('standard deviation:\t{:.4f}'.format(sigma))
print('standard error:\t\t{:.4f}'.format(sem))

confidenceLevel = .90
numOfTails      = 2
alpha           = (1 - confidenceLevel)/numOfTails

#  Percent Point Function
#  - calculates z-critical from (1-alpha)
z_critical = st.norm.ppf(1 - alpha)

# confidence Interval formula
lowerCI = mean - (z_critical * sigma)
upperCI = mean + (z_critical * sigma)

print('Step 2a:  Calculate z-critical for Confidence Level {:.0%} with {} tails.'.format(confidenceLevel,numOfTails))
print('Confidence Level:\t{:.0%}'.format(confidenceLevel))
print('Number of Tails:\t{}'.format(numOfTails))
print('alpha:\t\t\t{:.4f}'.format(alpha))
print('z-critical value:\t{:.4f}  <---'.format(z_critical))

print('\nConfidence Interval:\nlower CI\t\t{:.4f}'.format(lowerCI))
print('upper CI:\t\t{:.4f}'.format(upperCI))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# mean:			4.1171
# standard deviation:	0.1098
# standard error:		0.0016
# Step 2a:  Calculate z-critical for Confidence Level 90% with 2 tails.
# Confidence Level:	90%
# Number of Tails:	2
# alpha:			0.0500
# z-critical value:	1.6449  <---
#
# Confidence Interval:
# lower CI		3.9365
# upper CI:		4.2977

# %%
usda = 4.24
#  PLOT CONFIDENCE INTERVAL
plt.figure(figsize=(10,6))
plt.title('Micronaire for dg3799 b3xf\nz-statistics - Confidence Level = {:.0%} '.format(confidenceLevel), fontsize=16)
plt.xlabel('Micronaire')
plt.ylabel('density')

labelCI=("lower CI:  {:.4f}\nupper CI:   {:.4f}".format(lowerCI,upperCI))
#labelCI=("upper CI: {:.4f}\n".format(upperCI))
labelUS=("usda: {:.4f}".format(usda))
labelME=("\nmean:  {:.4f}".format(mean))

plt.vlines([lowerCI, upperCI],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelCI,color='blue',ls='--')
plt.vlines([usda],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelUS,color='red',ls='--')

plt.vlines(mean,0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)*.5),label=labelME,color='green')
plt.legend(loc='best')

sns.distplot(feature2, hist=True)
plt.show()


print("Z-Statistics - CONCLUSION:")
print("{:.0%} of the total patients in the Heart Disease UCI dataset will have cholesterol levels between {} and {}.".format(confidenceLevel, math.floor(lowerCI), math.ceil(upperCI)))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Z-Statistics - CONCLUSION:
# 90% of the total patients in the Heart Disease UCI dataset will have cholesterol levels between 3 and 5.

# %%
# Confidence Interval with Z-statistics for 3rd variety
plt.xlabel('Mic')
plt.ylabel('density')
plt.vlines(np.mean(feature3),0,0.003)
sns.distplot(feature3, hist=False)
plt.show()

#  mean, standard deviation and standard error
mean  = np.mean(feature3)           # mean
sigma = statistics.stdev(feature3)  # standard deviation
sem   = st.sem(feature3)   

print('mean:\t\t\t{:.4f}'.format(mean))
print('standard deviation:\t{:.4f}'.format(sigma))
print('standard error:\t\t{:.4f}'.format(sem))

confidenceLevel = .90
numOfTails      = 2
alpha           = (1 - confidenceLevel)/numOfTails

#  Percent Point Function
#  - calculates z-critical from (1-alpha)
z_critical = st.norm.ppf(1 - alpha)

# confidence Interval formula
lowerCI = mean - (z_critical * sigma)
upperCI = mean + (z_critical * sigma)

print('Step 2a:  Calculate z-critical for Confidence Level {:.0%} with {} tails.'.format(confidenceLevel,numOfTails))
print('Confidence Level:\t{:.0%}'.format(confidenceLevel))
print('Number of Tails:\t{}'.format(numOfTails))
print('alpha:\t\t\t{:.4f}'.format(alpha))
print('z-critical value:\t{:.4f}  <---'.format(z_critical))

print('\nConfidence Interval:\nlower CI\t\t{:.4f}'.format(lowerCI))
print('upper CI:\t\t{:.4f}'.format(upperCI))

usda = 4.24
#  PLOT CONFIDENCE INTERVAL
plt.figure(figsize=(10,6))
plt.title('Micronaire for dg3615 b3xf\nz-statistics - Confidence Level = {:.0%} '.format(confidenceLevel), fontsize=16)
plt.xlabel('Micronaire')
plt.ylabel('density')

labelCI=("lower CI:  {:.4f}\nupper CI:   {:.4f}".format(lowerCI,upperCI))
#labelCI=("upper CI: {:.4f}\n".format(upperCI))
labelUS=("usda: {:.4f}".format(usda))
labelME=("\nmean:  {:.4f}".format(mean))

plt.vlines([lowerCI, upperCI],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelCI,color='blue',ls='--')
plt.vlines([usda],0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)),label=labelUS,color='red',ls='--')

plt.vlines(mean,0,np.mean(st.norm.pdf(feature, loc=mean, scale=sigma)*.5),label=labelME,color='green')
plt.legend(loc='best')

sns.distplot(feature3, hist=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# mean:			4.1891
# standard deviation:	0.0727
# standard error:		0.0015
# Step 2a:  Calculate z-critical for Confidence Level 90% with 2 tails.
# Confidence Level:	90%
# Number of Tails:	2
# alpha:			0.0500
# z-critical value:	1.6449  <---
#
# Confidence Interval:
# lower CI		4.0696
# upper CI:		4.3086
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
